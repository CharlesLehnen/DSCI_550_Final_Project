# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/Moths!/
# Out:
# /content/drive/.shortcut-targets-by-id/1eUpt1BPaIIdC9e4XXCeb8lFeDx5LxbYm/Moths!

# %%
# Edit this each time to describe what you are changing

commit_message = "I tested it, repo has to be public to do this. So that is probably why my tokens keep getting revoked"

# %%
# Edit this once so that the changes are linked to you

git_token = "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"
username = "CharlesLehnen"
email = "lehnen@usc.edu"

# You can use this method instead if you don't want us to see your token
# import getpass
# git_token = getpass.getpass('Enter your GitHub token: ')

# %%
repository = "DSCI_550_Final_Project"

# !git config --global user.email "$email"
# !git config --global user.name "$username"

# %%
# !git pull
# Out:
# Already up to date.

# %%
# !git add .

# !git commit -m "$commit_message"
# Out:
# [main 1d90ff7] I just want to test if making the repo private will have an effect
#  2 files changed, 1 insertion(+), 16570 deletions(-)
#  rewrite github_scripts/charles_github.ipynb (96%)
#  delete mode 100644 moth_data.csv

# %%
# !git remote set-url origin https://{git_token}@github.com/{username}/{repository}.git
# !git push origin main
# Out:
# Enumerating objects: 7, done.
# Counting objects: 100% (7/7), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (5/5), 2.25 KiB | 576.00 KiB/s, done.
# Total 5 (delta 2), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (2/2), completed with 2 local objects.
# To https://github.com/CharlesLehnen/DSCI_550_Final_Project.git
#    9e9eb64..76e7ab0  main -> main
