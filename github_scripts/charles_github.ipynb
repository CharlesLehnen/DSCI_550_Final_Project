# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/Moths!/
# Out:
# /content/drive/.shortcut-targets-by-id/1eUpt1BPaIIdC9e4XXCeb8lFeDx5LxbYm/Moths!

# %%
# Edit this each time to describe what you are changing

commit_message = "Organizing the folder. Also I had to separate out git commands"

# %%
# Edit this once so that the changes are linked to you

git_token = "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"
username = "CharlesLehnen"
repository = "DSCI_550_Final_Project"

# !git config --global user.email "lehnen@usc.edu"
# !git config --global user.name "CharlesLehnen"

# %%
# !git pull
# Out:
# Already up to date.

# %%
# !git add .

# !git commit -m "$commit_message"
# Out:
# [main 9e9eb64] trying to see if I can run all the git commands in a single code block
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite charles_github.ipynb (64%)

# %%
# !git remote set-url origin https://{git_token}@github.com/{username}/{repository}.git
# !git push origin main
# Out:
# Enumerating objects: 11, done.
# Counting objects: 100% (11/11), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (9/9), done.
# Writing objects: 100% (9/9), 4.65 KiB | 280.00 KiB/s, done.
# Total 9 (delta 5), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (5/5), completed with 2 local objects.
# To https://github.com/CharlesLehnen/DSCI_550_Final_Project.git
#    adbc8fb..9e9eb64  main -> main
