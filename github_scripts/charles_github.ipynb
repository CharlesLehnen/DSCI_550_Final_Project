# %% [markdown]
# Edit the `commit_message` variable and then click Runtime > Restart and run all

# %%
# **Edit this each time to describe what you are changing**

commit_message = "seeing if I can delete more error handling stuff"

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# ```
# # cd to wherever the .git file is stored
# ```

# %%
cd /content/drive/MyDrive/Moths!/
# Out:
# /content/drive/.shortcut-targets-by-id/1eUpt1BPaIIdC9e4XXCeb8lFeDx5LxbYm/Moths!

# %%
# Edit this once so that the changes are linked to you

username = "CharlesLehnen"
email = "lehnen@usc.edu"

# %%
with open('/content/drive/MyDrive/github_token.txt', 'r') as file:
    git_token = file.readline().strip()

repository = "DSCI_550_Final_Project"

# !git config --global user.email "$email"
# !git config --global user.name "$username"

# %%
# Initialize GIT LFS

# !git lfs install
# !git add .gitattributes
# Out:
# Updated Git hooks.
# Git LFS initialized.

# %%
# !git add github_scripts/charles_github.ipynb

# !git commit -m "$commit_message"
# Out:
# fatal: cannot exec '.git/hooks/post-commit': Permission denied
# [main 78b05c9] okay. that GitHub hanging nightmare is over. deleting all of my notes
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite github_scripts/charles_github.ipynb (97%)

# %%
# To increase hang
# !git config http.postBuffer 524288000
# !git remote set-url origin https://{git_token}@github.com/{username}/{repository}.git
# !git push origin main
# Out:
# Enumerating objects: 7, done.
# Counting objects: 100% (7/7), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (4/4), 1.92 KiB | 280.00 KiB/s, done.
# Total 4 (delta 2), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (2/2), completed with 2 local objects.
# To https://github.com/CharlesLehnen/DSCI_550_Final_Project.git
#    d561a26..78b05c9  main -> main
