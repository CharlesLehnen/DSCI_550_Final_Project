# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/Moths!/
# Out:
# /content/drive/.shortcut-targets-by-id/1eUpt1BPaIIdC9e4XXCeb8lFeDx5LxbYm/Moths!

# %%
# Edit this each time to describe what you are changing

commit_message = "trying to see if I can run all the git commands in a single code block"

# %%
# Edit this once so that the

git_token = "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"
username = "CharlesLehnen"
repository = "DSCI_550_Final_Project"

# !git config --global user.email "lehnen@usc.edu"
# !git config --global user.name "CharlesLehnen"

# %%
# !git pull
# Out:
# Already up to date.

# %%
# !git add .

# !git commit -m "$commit_message"
# Out:
# [main 9a23b8a] trying to see if I can run all the git commands in a single code block
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite charles_github.ipynb (99%)

# %%
# !git remote set-url origin https://{git_token}@github.com/{username}/{repository}.git
# !git push origin main
# Out:
# fatal: could not read Password for 'https://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@github.com': No such device or address
