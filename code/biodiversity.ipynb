# %%
import pandas as pd
import geopandas as gpd

from google.colab import drive
drive.mount('/content/drive', force_remount=True)
import plotly.express as px
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv(f'/content/drive/My Drive/Mantises!/data/mantodea_ca_gbif_simple.csv', sep='\t')

# %%
df.head()
# Out:
#       gbifID                            datasetKey  \
# 0  923926829  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 1  923921190  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 2  923917961  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 3  899975780  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 4  891755288  50c9509d-22c7-4a22-a47d-8c48425ef4a7
#
#                                      occurrenceID   kingdom      phylum  \
# 0  http://www.inaturalist.org/observations/766957  Animalia  Arthropoda
# 1  http://www.inaturalist.org/observations/750035  Animalia  Arthropoda
# 2  http://www.inaturalist.org/observations/741586  Animalia  Arthropoda
# 3  http://www.inaturalist.org/observations/645036  Animalia  Arthropoda
# 4  http://www.inaturalist.org/observations/439613  Animalia  Arthropoda
#
#      class     order    family   genus           species  ...  \
# 0  Insecta  Mantodea  Mantidae  Mantis  Mantis religiosa  ...
# 1  Insecta  Mantodea  Mantidae  Mantis  Mantis religiosa  ...
# 2  Insecta  Mantodea  Mantidae  Mantis  Mantis religiosa  ...
# 3  Insecta  Mantodea  Mantidae  Mantis  Mantis religiosa  ...
# 4  Insecta  Mantodea  Mantidae  Mantis  Mantis religiosa  ...
#
#          identifiedBy       dateIdentified       license        rightsHolder  \
# 0  Callahan Charleton  2014-07-03T20:54:23  CC_BY_NC_4_0  Callahan Charleton
# 1          Tony Iwane  2014-06-23T01:27:47       CC0_1_0          Tony Iwane
# 2       Ken-ichi Ueda  2014-06-18T17:43:13  CC_BY_NC_4_0        Todd Plummer
# 3       Bruce Freeman  2014-04-27T06:25:51  CC_BY_NC_4_0          Eric Jacob
# 4     Paul G. Johnson  2013-10-25T04:13:21  CC_BY_NC_4_0     Paul G. Johnson
#
#            recordedBy typeStatus establishmentMeans           lastInterpreted  \
# 0  Callahan Charleton        NaN                NaN  2023-09-28T11:04:15.229Z
# 1          Tony Iwane        NaN                NaN  2023-09-28T12:35:45.908Z
# 2        Todd Plummer        NaN                NaN  2023-09-28T11:04:17.149Z
# 3          Eric Jacob        NaN                NaN  2023-09-28T12:34:59.254Z
# 4     Paul G. Johnson        NaN                NaN  2023-09-28T11:04:05.380Z
#
#     mediaType                                              issue
# 0  StillImage  CONTINENT_DERIVED_FROM_COORDINATES;TAXON_MATCH...
# 1  StillImage  COORDINATE_ROUNDED;CONTINENT_DERIVED_FROM_COOR...
# 2  StillImage  CONTINENT_DERIVED_FROM_COORDINATES;TAXON_MATCH...
# 3  StillImage  CONTINENT_DERIVED_FROM_COORDINATES;TAXON_MATCH...
# 4  StillImage  CONTINENT_DERIVED_FROM_COORDINATES;TAXON_MATCH...
#
# [5 rows x 50 columns]

# %%
gdf = gpd.read_file(f'/content/drive/My Drive/Mantises!/data/gadm41_USA_shp/gadm41_USA_0.shp')

# %%
gdf.head()
# Out:
#   GID_0        COUNTRY                                           geometry
# 0   USA  United States  MULTIPOLYGON (((-81.96265 24.52128, -81.96264 ...

# %%
gdf.plot()
# Out:
# <Axes: >

# %%
gdf_2 = gpd.read_file(f'/content/drive/My Drive/Mantises!/data/gadm41_USA_shp/gadm41_USA_1.shp')

# %%
gdf_2.plot()
# Out:
# <Axes: >

# %%
gdf_3 = gpd.read_file(f'/content/drive/My Drive/Mantises!/data/gadm41_USA_shp/gadm41_USA_2.shp')

# %%
gdf_3.head()
# Out:
#        GID_2 GID_0        COUNTRY    GID_1   NAME_1 NL_NAME_1   NAME_2  \
# 0  USA.1.1_1   USA  United States  USA.1_1  Alabama        NA  Autauga
# 1  USA.1.2_1   USA  United States  USA.1_1  Alabama        NA  Baldwin
# 2  USA.1.3_1   USA  United States  USA.1_1  Alabama        NA  Barbour
# 3  USA.1.4_1   USA  United States  USA.1_1  Alabama        NA     Bibb
# 4  USA.1.5_1   USA  United States  USA.1_1  Alabama        NA   Blount
#
#   VARNAME_2 NL_NAME_2  TYPE_2 ENGTYPE_2 CC_2    HASC_2  \
# 0        NA        NA  County    County   NA  US.AL.AU
# 1        NA        NA  County    County   NA  US.AL.BD
# 2        NA        NA  County    County   NA  US.AL.BR
# 3        NA        NA  County    County   NA  US.AL.BI
# 4        NA        NA  County    County   NA  US.AL.BU
#
#                                             geometry
# 0  POLYGON ((-86.91668 32.66431, -86.82678 32.660...
# 1  MULTIPOLYGON (((-87.74416 30.29445, -87.74389 ...
# 2  POLYGON ((-85.41607 31.61962, -85.49133 31.620...
# 3  POLYGON ((-87.42078 32.87446, -87.42028 32.971...
# 4  POLYGON ((-86.96287 33.85858, -86.96512 33.863...

# %%
gdf_3 = gdf_3[(gdf_3['NAME_1'] == 'California') & (gdf_3['TYPE_2'] == 'County')]

# %%
gdf_3.plot()
# Out:
# <Axes: >

# %%
df.columns
# Out:
# Index(['gbifID', 'datasetKey', 'occurrenceID', 'kingdom', 'phylum', 'class',
#        'order', 'family', 'genus', 'species', 'infraspecificEpithet',
#        'taxonRank', 'scientificName', 'verbatimScientificName',
#        'verbatimScientificNameAuthorship', 'countryCode', 'locality',
#        'stateProvince', 'occurrenceStatus', 'individualCount',
#        'publishingOrgKey', 'decimalLatitude', 'decimalLongitude',
#        'coordinateUncertaintyInMeters', 'coordinatePrecision', 'elevation',
#        'elevationAccuracy', 'depth', 'depthAccuracy', 'eventDate', 'day',
#        'month', 'year', 'taxonKey', 'speciesKey', 'basisOfRecord',
#        'institutionCode', 'collectionCode', 'catalogNumber', 'recordNumber',
#        'identifiedBy', 'dateIdentified', 'license', 'rightsHolder',
#        'recordedBy', 'typeStatus', 'establishmentMeans', 'lastInterpreted',
#        'mediaType', 'issue'],
#       dtype='object')

# %%
species_df = df[['species', 'decimalLatitude', 'decimalLongitude']]

# %%
species_df.head()
# Out:
#             species  decimalLatitude  decimalLongitude
# 0  Mantis religiosa        38.569964       -122.689257
# 1  Mantis religiosa        37.905477       -121.959702
# 2  Mantis religiosa        38.569659       -122.689175
# 3  Mantis religiosa        34.424911       -119.798001
# 4  Mantis religiosa        36.513572       -121.187010

# %%
from shapely.geometry import Point

# Create a new geometry column in your pandas dataframe
geometry = [Point(xy) for xy in zip(species_df.decimalLongitude, species_df.decimalLatitude)]
geo_species_df = gpd.GeoDataFrame(species_df, geometry=geometry)

# %%
geo_species_df.set_crs(epsg=4326, inplace=True)

gdf_3.set_crs(epsg=4326, inplace=True)
# If necessary, transform one of the dataframes to match the other's CRS
geo_species_df = geo_species_df.to_crs(gdf_3.crs)

# %%
geo_species_df.head()
# Out:
#             species  decimalLatitude  decimalLongitude  \
# 0  Mantis religiosa        38.569964       -122.689257
# 1  Mantis religiosa        37.905477       -121.959702
# 2  Mantis religiosa        38.569659       -122.689175
# 3  Mantis religiosa        34.424911       -119.798001
# 4  Mantis religiosa        36.513572       -121.187010
#
#                       geometry
# 0  POINT (-122.68926 38.56996)
# 1  POINT (-121.95970 37.90548)
# 2  POINT (-122.68918 38.56966)
# 3  POINT (-119.79800 34.42491)
# 4  POINT (-121.18701 36.51357)

# %%
joined = gpd.sjoin(geo_species_df, gdf_3, how="inner", op="intersects")
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py:3473: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if (await self.run_code(code, result,  async_=asy)):

# %%
print(geo_species_df.crs)
print(gdf_3.crs)
# Out:
# EPSG:4326
# EPSG:4326

# %%
gdf_3.head()
# Out:
#          GID_2 GID_0        COUNTRY    GID_1      NAME_1 NL_NAME_1     NAME_2  \
# 183  USA.5.1_1   USA  United States  USA.5_1  California        NA    Alameda
# 184  USA.5.2_1   USA  United States  USA.5_1  California        NA     Alpine
# 185  USA.5.3_1   USA  United States  USA.5_1  California        NA     Amador
# 186  USA.5.4_1   USA  United States  USA.5_1  California        NA      Butte
# 187  USA.5.5_1   USA  United States  USA.5_1  California        NA  Calaveras
#
#     VARNAME_2 NL_NAME_2  TYPE_2 ENGTYPE_2 CC_2    HASC_2  \
# 183        NA        NA  County    County   NA  US.CA.AA
# 184        NA        NA  County    County   NA  US.CA.AP
# 185        NA        NA  County    County   NA  US.CA.AM
# 186        NA        NA  County    County   NA  US.CA.BU
# 187        NA        NA  County    County   NA  US.CA.CA
#
#                                               geometry
# 183  MULTIPOLYGON (((-121.99055 37.46256, -121.9907...
# 184  POLYGON ((-120.07266 38.51175, -120.07193 38.5...
# 185  POLYGON ((-120.07414 38.70165, -120.07320 38.6...
# 186  POLYGON ((-121.90864 39.30519, -121.90672 39.3...
# 187  POLYGON ((-120.07266 38.51175, -120.07199 38.5...

# %%
joined.head()
# Out:
#              species  decimalLatitude  decimalLongitude  \
# 0   Mantis religiosa        38.569964       -122.689257
# 2   Mantis religiosa        38.569659       -122.689175
# 9   Mantis religiosa        38.624724       -122.871580
# 10  Mantis religiosa        38.575230       -122.693980
# 11  Mantis religiosa        38.584350       -122.699930
#
#                        geometry  index_right       GID_2 GID_0        COUNTRY  \
# 0   POINT (-122.68926 38.56996)          231  USA.5.49_1   USA  United States
# 2   POINT (-122.68918 38.56966)          231  USA.5.49_1   USA  United States
# 9   POINT (-122.87158 38.62472)          231  USA.5.49_1   USA  United States
# 10  POINT (-122.69398 38.57523)          231  USA.5.49_1   USA  United States
# 11  POINT (-122.69993 38.58435)          231  USA.5.49_1   USA  United States
#
#       GID_1      NAME_1 NL_NAME_1  NAME_2 VARNAME_2 NL_NAME_2  TYPE_2  \
# 0   USA.5_1  California        NA  Sonoma        NA        NA  County
# 2   USA.5_1  California        NA  Sonoma        NA        NA  County
# 9   USA.5_1  California        NA  Sonoma        NA        NA  County
# 10  USA.5_1  California        NA  Sonoma        NA        NA  County
# 11  USA.5_1  California        NA  Sonoma        NA        NA  County
#
#    ENGTYPE_2 CC_2    HASC_2
# 0     County   NA  US.CA.SO
# 2     County   NA  US.CA.SO
# 9     County   NA  US.CA.SO
# 10    County   NA  US.CA.SO
# 11    County   NA  US.CA.SO

# %%
gdf_3[gdf_3.geometry.is_valid == False].geometry.buffer(0)
# Out:
# GeoSeries([], dtype: geometry)

# %%
geo_species_df[geo_species_df.geometry.is_valid == False].geometry.buffer(0)
# Out:
# GeoSeries([], dtype: geometry)

# %%
geo_species_df = geo_species_df.dropna(subset=['geometry'])

geo_species_df.plot()
# Out:
# <Axes: >

# %%
print(geo_species_df.total_bounds)
# Out:
# [-124.357638   32.534753 -114.467778   41.993293]

# %%
gdf_3.total_bounds
# Out:
# array([-124.415558  ,   32.530884  , -114.12948608,   42.00983048])

# %%
counties_to_species = {}

for index, row in joined.iterrows():
    if str(row['species']) != 'nan':
        if row['NAME_2'] in counties_to_species:
            counties_to_species[row['NAME_2']].add(row['species'])

        else:
            counties_to_species[row['NAME_2']] = set()
            counties_to_species[row['NAME_2']].add(row['species'])

# %%
print(counties_to_species)
# Out:
# {'Sonoma': {'Mantis religiosa', 'Stagmomantis californica', 'Litaneutria pacifica'}, 'Contra Costa': {'Litaneutria pacifica', 'Stagmomantis limbata', 'Stagmomantis californica', 'Iris oratoria', 'Litaneutria ocularis', 'Mantis religiosa'}, 'Santa Barbara': {'Litaneutria pacifica', 'Litaneutria minor', 'Stagmomantis limbata', 'Stagmomantis californica', 'Mantis religiosa'}, 'San Benito': {'Litaneutria pacifica', 'Litaneutria minor', 'Iris oratoria', 'Tenodera sinensis', 'Mantis religiosa'}, 'Sacramento': {'Iris oratoria', 'Mantis religiosa', 'Stagmomantis californica', 'Stagmomantis limbata'}, 'San Francisco': {'Mantis religiosa', 'Tenodera sinensis'}, 'Santa Clara': {'Litaneutria pacifica', 'Stagmomantis limbata', 'Stagmomantis californica', 'Tenodera sinensis', 'Mantis religiosa'}, 'Alameda': {'Hierodula patellifera', 'Litaneutria pacifica', 'Stagmomantis limbata', 'Iris oratoria', 'Litaneutria ocularis', 'Tenodera sinensis', 'Mantis religiosa'}, 'San Mateo': {'Iris oratoria', 'Mantis religiosa', 'Tenodera sinensis', 'Stagmomantis limbata'}, 'Ventura': {'Stagmomantis limbata', 'Stagmomantis californica', 'Iris oratoria', 'Litaneutria ocularis', 'Tenodera sinensis', 'Mantis religiosa'}, 'Mariposa': {'Mantis religiosa', 'Litaneutria skinneri', 'Stagmomantis limbata'}, 'Butte': {'Stagmomantis limbata', 'Stagmomantis californica', 'Iris oratoria', 'Litaneutria ocularis', 'Mantis religiosa'}, 'Orange': {'Litaneutria pacifica', 'Stagmomantis limbata', 'Stagmomantis californica', 'Iris oratoria', 'Litaneutria chaparrali', 'Tenodera sinensis'}, 'Los Angeles': {'Litaneutria pacifica', 'Stagmomantis limbata', 'Litaneutria minor', 'Stagmomantis californica', 'Miomantis caffra', 'Iris oratoria', 'Litaneutria ocularis', 'Tenodera sinensis', 'Mantis religiosa'}, 'San Bernardino': {'Litaneutria pacifica', 'Stagmomantis limbata', 'Litaneutria minor', 'Stagmomantis californica', 'Iris oratoria', 'Litaneutria ocularis', 'Mantis religiosa'}, 'Mendocino': {'Mantis religiosa', 'Stagmomantis californica'}, 'San Diego': {'Litaneutria pacifica', 'Stagmomantis limbata', 'Litaneutria minor', 'Stagmomantis californica', 'Miomantis caffra', 'Iris oratoria', 'Litaneutria ocularis', 'Tenodera sinensis', 'Mantis religiosa'}, 'Amador': {'Mantis religiosa', 'Stagmomantis limbata'}, 'Solano': {'Iris oratoria', 'Mantis religiosa', 'Stagmomantis limbata'}, 'Yolo': {'Iris oratoria', 'Mantis religiosa', 'Stagmomantis limbata'}, 'Merced': {'Litaneutria pacifica', 'Stagmomantis limbata', 'Stagmomantis californica', 'Iris oratoria', 'Tenodera sinensis', 'Mantis religiosa'}, 'Riverside': {'Litaneutria pacifica', 'Stagmomantis limbata', 'Stagmomantis californica', 'Iris oratoria', 'Litaneutria ocularis', 'Mantis religiosa'}, 'Marin': {'Mantis religiosa', 'Litaneutria pacifica', 'Tenodera sinensis'}, 'Placer': {'Iris oratoria', 'Mantis religiosa', 'Stagmomantis limbata'}, 'Shasta': {'Iris oratoria', 'Mantis religiosa', 'Stagmomantis limbata'}, 'Calaveras': {'Mantis religiosa', 'Stagmomantis limbata'}, 'Imperial': {'Litaneutria pacifica', 'Litaneutria minor', 'Stagmomantis limbata', 'Iris oratoria', 'Litaneutria ocularis'}, 'Stanislaus': {'Iris oratoria', 'Mantis religiosa', 'Stagmomantis californica', 'Stagmomantis limbata'}, 'Nevada': {'Mantis religiosa', 'Stagmomantis californica', 'Litaneutria pacifica', 'Stagmomantis limbata'}, 'Siskiyou': {'Mantis religiosa', 'Litaneutria pacifica'}, 'San Luis Obispo': {'Iris oratoria', 'Mantis religiosa', 'Litaneutria pacifica', 'Stagmomantis limbata'}, 'Humboldt': {'Mantis religiosa'}, 'Mono': {'Litaneutria skinneri', 'Mantis religiosa', 'Stagmomantis limbata'}, 'Napa': {'Mantis religiosa', 'Stagmomantis limbata'}, 'Fresno': {'Litaneutria pacifica', 'Stagmomantis limbata', 'Litaneutria minor', 'Iris oratoria', 'Litaneutria ocularis', 'Mantis religiosa'}, 'Glenn': {'Iris oratoria', 'Mantis religiosa'}, 'Sutter': {'Mantis religiosa', 'Stagmomantis limbata'}, 'Inyo': {'Litaneutria pacifica', 'Stagmomantis limbata', 'Stagmomantis ca ...

# %%
gdf_3 = gdf_3[['NAME_2', 'geometry']]

# %%
gdf_3
# Out:
#               NAME_2                                           geometry
# 183          Alameda  MULTIPOLYGON (((-121.99055 37.46256, -121.9907...
# 184           Alpine  POLYGON ((-120.07266 38.51175, -120.07193 38.5...
# 185           Amador  POLYGON ((-120.07414 38.70165, -120.07320 38.6...
# 186            Butte  POLYGON ((-121.90864 39.30519, -121.90672 39.3...
# 187        Calaveras  POLYGON ((-120.07266 38.51175, -120.07199 38.5...
# 188           Colusa  POLYGON ((-121.88808 39.38493, -121.88734 39.3...
# 189     Contra Costa  POLYGON ((-122.31773 37.89746, -122.31839 37.8...
# 190        Del Norte  MULTIPOLYGON (((-123.53883 41.98751, -123.5392...
# 191        El Dorado  POLYGON ((-119.90250 38.93323, -119.90025 38.9...
# 192           Fresno  POLYGON ((-120.91826 36.74143, -120.91035 36.7...
# 193            Glenn  POLYGON ((-122.04560 39.80083, -122.04187 39.7...
# 194         Humboldt  MULTIPOLYGON (((-124.05174 41.46503, -123.9940...
# 195         Imperial  POLYGON ((-114.72063 32.71796, -114.72024 32.7...
# 196             Inyo  POLYGON ((-118.36443 36.74711, -118.37177 36.7...
# 197             Kern  POLYGON ((-118.00905 35.78609, -117.92342 35.7...
# 198            Kings  POLYGON ((-120.31820 35.90518, -120.29678 35.9...
# 199             Lake  POLYGON ((-122.73894 39.38343, -122.78485 39.3...
# 200           Lassen  POLYGON ((-121.32722 40.44508, -121.32719 40.4...
# 201      Los Angeles  MULTIPOLYGON (((-118.43278 32.80250, -118.4327...
# 202           Madera  POLYGON ((-119.02357 37.58572, -119.06151 37.5...
# 203            Marin  MULTIPOLYGON (((-122.42889 37.87150, -122.4287...
# 204         Mariposa  POLYGON ((-119.30767 37.77914, -119.37997 37.7...
# 205        Mendocino  MULTIPOLYGON (((-123.59254 38.79800, -123.5933...
# 206           Merced  POLYGON ((-120.54173 37.04589, -120.89619 36.7...
# 207            Modoc  POLYGON ((-119.99953 41.18446, -120.04977 41.1...
# 208             Mono  POLYGON ((-119.63650 38.32855, -119.63535 38.3...
# 209         Monterey  POLYGON ((-120.67992 36.26598, -120.67412 36.2...
# 210             Napa  POLYGON ((-122.62583 38.66755, -122.46342 38.7...
# 211           Nevada  POLYGON ((-121.27880 39.03651, -121.27909 39.1...
# 212           Orange  POLYGON ((-118.11372 33.74250, -118.11414 33.7...
# 213           Placer  POLYGON ((-120.00225 39.06773, -120.12741 39.0...
# 214           Plumas  POLYGON ((-121.07590 39.59776, -121.07901 39.6...
# 215        Riverside  POLYGON ((-114.43308 34.08561, -114.43413 34.0...
# 216       Sacramento  MULTIPOLYGON (((-121.83778 38.03139, -121.8436...
# 217       San Benito  POLYGON ((-120.91826 36.74143, -120.82331 36.6...
# 218   San Bernardino  POLYGON ((-114.13727 34.30508, -114.13660 34.3...
# 219        San Diego  MULTIPOLYGON (((-117.23302 32.77584, -117.2329...
# 220    San Francisco  MULTIPOLYGON (((-123.00222 37.70334, -123.0034...
# 221      San Joaquin  POLYGON ((-121.47069 37.48185, -121.47002 37.4...
# 222  San Luis Obispo  MULTIPOLYGON (((-120.87250 35.21583, -120.8727...
# 223        San Mateo  MULTIPOLYGON (((-122.33660 37.10862, -122.3357...
# 224    Santa Barbara  MULTIPOLYGON (((-119.04417 33.46556, -119.0445...
# 225      Santa Clara  MULTIPOLYGON (((-121.99090 37.46262, -121.9908...
# 226       Santa Cruz  POLYGON ((-121.64341 36.89353, -121.64597 36.9...
# 227           Shasta  POLYGON ((-121.33230 41.18410, -121.33208 41.1...
# 228           Sierra  POLYGON ((-120.14854 39.70892, -120.14017 39.7...
# 229         Siskiyou  POLYGON ((-123.65913 41.38206, -123.65639 41.3...
# 230           Solano  MULTIPOLYGON (((-121.97472 38.07306, -121.9744...
# 231           Sonoma  MULTIPOLYGON (((-122.49861 38.11069, -122.4986...
# 232       Stanislaus  POLYGON ((-120.92587 38.07786, -120.72584 37.8...
# 233           Sutter  POLYGON ((-121.90864 39.30519, -121.85389 39.3...
# 234           Tehama  POLYGON ((-121.44427 40.15079, -121.44370 40.1...
# 235          Trinity  POLYGON ((-123.54378 40.00379, -123.54397 40.1...
# 236           Tulare  POLYGON ((-119.57764 36.48855, -119.47060 36.5...
# 237         Tuolumne  POLYGON ((-120.01685 38.43630, -119.87933 38.3...
# 238          Ventura  MULTIPOLYGON (((-119.52468 33.28344, -119.5241...
# 239             Yolo  POLYGON ((-122.33863 38.92477, -122.31378 38.9...
# 240             Yuba  POLYGON ((-121.62526 39.29493, -121.62012 39.3...

# %%
counties_to_species_counts = {}

for c in counties_to_species:

    counties_to_species_counts[c] = len(counties_to_species[c])

# %%
counties_to_species_counts
# Out:
# {'Sonoma': 3,
#  'Contra Costa': 6,
#  'Santa Barbara': 5,
#  'San Benito': 5,
#  'Sacramento': 4,
#  'San Francisco': 2,
#  'Santa Clara': 5,
#  'Alameda': 7,
#  'San Mateo': 4,
#  'Ventura': 6,
#  'Mariposa': 3,
#  'Butte': 5,
#  'Orange': 6,
#  'Los Angeles': 9,
#  'San Bernardino': 7,
#  'Mendocino': 2,
#  'San Diego': 9,
#  'Amador': 2,
#  'Solano': 3,
#  'Yolo': 3,
#  'Merced': 6,
#  'Riverside': 6,
#  'Marin': 3,
#  'Placer': 3,
#  'Shasta': 3,
#  'Calaveras': 2,
#  'Imperial': 5,
#  'Stanislaus': 4,
#  'Nevada': 4,
#  'Siskiyou': 2,
#  'San Luis Obispo': 4,
#  'Humboldt': 1,
#  'Mono': 3,
#  'Napa': 2,
#  'Fresno': 6,
#  'Glenn': 2,
#  'Sutter': 2,
#  'Inyo': 8,
#  'San Joaquin': 5,
#  'Lake': 3,
#  'Kern': 7,
#  'Tehama': 3,
#  'Trinity': 1,
#  'Lassen': 1,
#  'El Dorado': 3,
#  'Tuolumne': 5,
#  'Santa Cruz': 2,
#  'Tulare': 4,
#  'Monterey': 2,
#  'Yuba': 4,
#  'Madera': 4,
#  'Modoc': 1,
#  'Plumas': 1,
#  'Kings': 3,
#  'Del Norte': 2,
#  'Sierra': 1,
#  'Colusa': 3,
#  'Alpine': 1}

# %%
gdf_3['species_count'] = gdf_3.apply(lambda row: counties_to_species_counts.get(row['NAME_2'], 0), axis=1)
# Out:
# /usr/local/lib/python3.10/dist-packages/geopandas/geodataframe.py:1538: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)

# %%
gdf_3
# Out:
#               NAME_2                                           geometry  \
# 183          Alameda  MULTIPOLYGON (((-121.99055 37.46256, -121.9907...
# 184           Alpine  POLYGON ((-120.07266 38.51175, -120.07193 38.5...
# 185           Amador  POLYGON ((-120.07414 38.70165, -120.07320 38.6...
# 186            Butte  POLYGON ((-121.90864 39.30519, -121.90672 39.3...
# 187        Calaveras  POLYGON ((-120.07266 38.51175, -120.07199 38.5...
# 188           Colusa  POLYGON ((-121.88808 39.38493, -121.88734 39.3...
# 189     Contra Costa  POLYGON ((-122.31773 37.89746, -122.31839 37.8...
# 190        Del Norte  MULTIPOLYGON (((-123.53883 41.98751, -123.5392...
# 191        El Dorado  POLYGON ((-119.90250 38.93323, -119.90025 38.9...
# 192           Fresno  POLYGON ((-120.91826 36.74143, -120.91035 36.7...
# 193            Glenn  POLYGON ((-122.04560 39.80083, -122.04187 39.7...
# 194         Humboldt  MULTIPOLYGON (((-124.05174 41.46503, -123.9940...
# 195         Imperial  POLYGON ((-114.72063 32.71796, -114.72024 32.7...
# 196             Inyo  POLYGON ((-118.36443 36.74711, -118.37177 36.7...
# 197             Kern  POLYGON ((-118.00905 35.78609, -117.92342 35.7...
# 198            Kings  POLYGON ((-120.31820 35.90518, -120.29678 35.9...
# 199             Lake  POLYGON ((-122.73894 39.38343, -122.78485 39.3...
# 200           Lassen  POLYGON ((-121.32722 40.44508, -121.32719 40.4...
# 201      Los Angeles  MULTIPOLYGON (((-118.43278 32.80250, -118.4327...
# 202           Madera  POLYGON ((-119.02357 37.58572, -119.06151 37.5...
# 203            Marin  MULTIPOLYGON (((-122.42889 37.87150, -122.4287...
# 204         Mariposa  POLYGON ((-119.30767 37.77914, -119.37997 37.7...
# 205        Mendocino  MULTIPOLYGON (((-123.59254 38.79800, -123.5933...
# 206           Merced  POLYGON ((-120.54173 37.04589, -120.89619 36.7...
# 207            Modoc  POLYGON ((-119.99953 41.18446, -120.04977 41.1...
# 208             Mono  POLYGON ((-119.63650 38.32855, -119.63535 38.3...
# 209         Monterey  POLYGON ((-120.67992 36.26598, -120.67412 36.2...
# 210             Napa  POLYGON ((-122.62583 38.66755, -122.46342 38.7...
# 211           Nevada  POLYGON ((-121.27880 39.03651, -121.27909 39.1...
# 212           Orange  POLYGON ((-118.11372 33.74250, -118.11414 33.7...
# 213           Placer  POLYGON ((-120.00225 39.06773, -120.12741 39.0...
# 214           Plumas  POLYGON ((-121.07590 39.59776, -121.07901 39.6...
# 215        Riverside  POLYGON ((-114.43308 34.08561, -114.43413 34.0...
# 216       Sacramento  MULTIPOLYGON (((-121.83778 38.03139, -121.8436...
# 217       San Benito  POLYGON ((-120.91826 36.74143, -120.82331 36.6...
# 218   San Bernardino  POLYGON ((-114.13727 34.30508, -114.13660 34.3...
# 219        San Diego  MULTIPOLYGON (((-117.23302 32.77584, -117.2329...
# 220    San Francisco  MULTIPOLYGON (((-123.00222 37.70334, -123.0034...
# 221      San Joaquin  POLYGON ((-121.47069 37.48185, -121.47002 37.4...
# 222  San Luis Obispo  MULTIPOLYGON (((-120.87250 35.21583, -120.8727...
# 223        San Mateo  MULTIPOLYGON (((-122.33660 37.10862, -122.3357...
# 224    Santa Barbara  MULTIPOLYGON (((-119.04417 33.46556, -119.0445...
# 225      Santa Clara  MULTIPOLYGON (((-121.99090 37.46262, -121.9908...
# 226       Santa Cruz  POLYGON ((-121.64341 36.89353, -121.64597 36.9...
# 227           Shasta  POLYGON ((-121.33230 41.18410, -121.33208 41.1...
# 228           Sierra  POLYGON ((-120.14854 39.70892, -120.14017 39.7...
# 229         Siskiyou  POLYGON ((-123.65913 41.38206, -123.65639 41.3...
# 230           Solano  MULTIPOLYGON (((-121.97472 38.07306, -121.9744...
# 231           Sonoma  MULTIPOLYGON (((-122.49861 38.11069, -122.4986...
# 232       Stanislaus  POLYGON ((-120.92587 38.07786, -120.72584 37.8...
# 233           Sutter  POLYGON ((-121.90864 39.30519, -121.85389 39.3...
# 234           Tehama  POLYGON ((-121.44427 40.15079, -121.44370 40.1...
# 235          Trinity  POLYGON ((-123.54378 40.00379, -123.54397 40.1...
# 236           Tulare  POLYGON ((-119.57764 36.48855, -119.47060 36.5...
# 237         Tuolumne  POLYGON ((-120.01685 38.43630, -119.87933 38.3...
# 238          Ventura  MULTIPOLYGON (((-119.52468 33.28344, -119.5241...
# 239             Yolo  POLYGON ((-122.33863 38.92477, -122.31378 38.9...
# 240             Yuba  POLYGON ((-121.62526 39.29493, -121.62012 39.3...
#
#      species_count
# 183              7
# 184              1
# 185              2
# 186              5
# 187              2
# 188              3
# 189              6
# 190              2
# 191              3
# 192              6
# 193              2
# 194              1
# 195              5
# 196              8
# 197              7
# 198              3
# 199              3
# 200              1
# 201              9
# 202              4
# 203              3
# 204              3
# 205              2
# 206              6
# 207              1
# 208              3
# 209              2
# 210              2
# 211              4
# 212              6
# 213              3
# 214              1
# 215              6
# 216              4
# 217              5
# 218              7
# 219              9
# 220              2
# 221              5
# 222              4
# 223              4
# 224              5
# 225              5
# 226              2
# 227              3
# 228              1
# 229              2
# 230              3
# 231              3
# 232              4
# 233              2
# 234              3
# 235              1
# 236              4
# 237              5
# 238              6
# 239              3
# 240              4

# %%
# !apt-get install libproj-dev proj-data proj-bin
# !apt-get install libgeos-dev
# !pip install cython
# !pip install cartopy
# !pip install geoplot
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# libproj-dev is already the newest version (8.2.1-1).
# libproj-dev set to manually installed.
# proj-data is already the newest version (8.2.1-1).
# proj-data set to manually installed.
# The following NEW packages will be installed:
#   proj-bin
# 0 upgraded, 1 newly installed, 0 to remove and 19 not upgraded.
# Need to get 154 kB of archives.
# After this operation, 492 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 proj-bin amd64 8.2.1-1 [154 kB]
# Fetched 154 kB in 0s (584 kB/s)
# Selecting previously unselected package proj-bin.
# (Reading database ... 120874 files and directories currently installed.)
# Preparing to unpack .../proj-bin_8.2.1-1_amd64.deb ...
# Unpacking proj-bin (8.2.1-1) ...
# Setting up proj-bin (8.2.1-1) ...
# Processing triggers for man-db (2.10.2-1) ...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# libgeos-dev is already the newest version (3.10.2-1).
# libgeos-dev set to manually installed.
# 0 upgraded, 0 newly installed, 0 to remove and 19 not upgraded.
# Requirement already satisfied: cython in /usr/local/lib/python3.10/dist-packages (3.0.4)
# Collecting cartopy
#   Downloading Cartopy-0.22.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 70.7 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.21 in /usr/local/lib/python3.10/dist-packages (from cartopy) (1.23.5)
# Requirement already satisfied: matplotlib>=3.4 in /usr/local/lib/python3.10/dist-packages (from cartopy) (3.7.1)
# Requirement already satisfied: shapely>=1.7 in /usr/local/lib/python3.10/dist-packages (from cartopy) (2.0.2)
# Requirement already satisfied: packaging>=20 in /usr/local/lib/python3.10/dist-packages (from cartopy) (23.2)
# Requirement already satisfied: pyshp>=2.1 in /usr/local/lib/python3.10/dist-packages (from cartopy) (2.3.1)
# Requirement already satisfied: pyproj>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from cartopy) (3.6.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.4->cartopy) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.4->cartopy) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.4->cartopy) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.4->cartopy) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.4->cartopy) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.4->cartopy) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.4->cartopy) (2.8.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from pyproj>=3.1.0->cartopy) (2023.7.22)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.4->cartopy) (1.16.0)
# Installing collected packages: cartopy
# Successfully installed cartopy-0.22.0
# Collecting geoplot
#   Downloading geoplot-0.5.1-py3-none-any.whl (28 kB)
# Requirement already satisfied: matplotlib>=3.1.2 in /usr/local/lib/python3.10/dist-packages (from geoplot) (3.7.1)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.10/dist-packages (from geoplot) (0.12.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from geoplot) (1.5.3)
# Requirement already satisfied: geopandas>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from geoplot) (0.13.2)
# Requirement already satisfied: cartopy in /usr/local/lib/python3.10/dist-packages (from geoplot) (0.22.0)
# Collecting mapclassify>=2.1 (from geoplot)
#   Downloading mapclassify-2.6.1-py3-none-any.whl (38 kB)
# Collecting contextily>=1.0.0 (from geoplot)
#   Downloading contextily-1.4.0-py3-none-any.whl (16 kB)
# Requirement already satisfied: geopy in /usr/local/lib/python3.10/dist-packages (from contextily>=1.0.0->geoplot) (2.3.0)
# Collecting mercantile (from contextily>=1.0.0->geoplot)
#   Downloading mercantile-1.2.1-py3-none-any.whl (14 kB)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from contextily>=1.0.0->geoplot) (9.4.0)
# Collecting rasterio (from contextily>=1.0.0->geoplot)
#   Downloading rasterio-1.3.9-cp310-cp310-manylinux2014_x86_64.whl (20.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.6/20.6 MB 64.4 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from contextily>=1.0.0->geoplot) (2.31.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from contextily>=1.0.0->geoplot) (1.3.2)
# Requirement already satisfied: xyzservices in /usr/local/lib/python3.10/dist-packages (from contextily>=1.0.0->geoplot) (2023.10.0)
# Requirement already satisfied: fiona>=1.8.19 in /usr/local/lib/python3.10/dist-packages (from geopandas>=0.9.0->geoplot) (1.9.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from geopandas>=0.9.0->geoplot) (23.2)
# Requirement already satisfied: pyproj>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from geopandas>=0.9.0->geoplot) (3.6.1)
# Requirement already satisfied: shapely>=1.7.1 in /usr/local/lib/python3.10/dist-packages (from geopandas>=0.9.0->geoplot) (2.0.2)
# Requirement already satisfied: networkx>=2.7 in /usr/local/lib/python3.10/dist-packages (from mapclassify>=2.1->geoplot) (3.2)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.10/dist-packages (from mapclassify>=2.1->geoplot) (1.23.5)
# Requirement already satisfied: scikit-learn>=1.0 in /usr/local/lib/python3.10/dist-packages (from mapclassify>=2.1->geoplot) (1.2.2)
# Requirement already satisfied: scipy>=1.8 in /usr/local/lib/python3.10/dist-packages (from mapclassify>=2.1->geoplot) (1.11.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.2->geoplot) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.2->geoplot) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.2->geoplot) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.2->geoplot) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.2->geoplot) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.2->geoplot) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->geoplot) (2023.3.post1)
# Requirement already satisfied: pyshp>=2.1 in /usr/local/lib/python3.10/dist-packages (from cartopy->geoplot) (2.3.1)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas>=0.9.0->geoplot) (23.1.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas>=0.9.0->geoplot) (2023.7.22)
# Requirement already satisfied: click~=8.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas>=0.9.0->geoplot) (8.1.7)
# Requirement already satisfied: click-plugins>=1.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas>=0.9.0->geoplot) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas>=0.9.0->geoplot) (0.7.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas>=0.9.0->geoplot) (1.16.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas>=0.9.0->geoplot) (67.7.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0->mapclassify>=2.1->geoplot) (3.2.0)
# Requirement already satisfied: geographiclib<3,>=1.52 in /usr/local/lib/python3.10/dist-packages (from geopy->contextily>=1.0.0->geoplot) (2.0)
# Collecting affine (from rasterio->contextily>=1.0.0->geoplot)
#   Downloading affine-2.4.0-py3-none-any.whl (15 kB)
# Collecting snuggs>=1.4.1 (from rasterio->contextily>=1.0.0->geoplot)
#   Downloading snuggs-1.4.7-py3-none-any.whl (5.4 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->contextily>=1.0.0->geoplot) (3.3.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->contextily>=1.0.0->geoplot) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->contextily>=1.0.0->geoplot) (2.0.7)
# Installing collected packages: snuggs, mercantile, affine, rasterio, mapclassify, contextily, geoplot
# Successfully installed affine-2.4.0 contextily-1.4.0 geoplot-0.5.1 mapclassify-2.6.1 mercantile-1.2.1 rasterio-1.3.9 snuggs-1.4.7

# %%
import geoplot as gplt
import geoplot.crs as gcrs
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots(1, figsize=(8, 8))
plt.xticks(rotation=90)
bar_info = plt.cm.ScalarMappable(cmap="plasma", norm=plt.Normalize(vmin=0, vmax=9))
bar_info._A = []
cbar = fig.colorbar(bar_info)
gdf_3.plot(column="species_count", cmap="plasma", linewidth=0.4, ax=ax, edgecolor=".4")
# Out:
# <ipython-input-39-d2831d24b545>:5: MatplotlibDeprecationWarning: Unable to determine Axes to steal space for Colorbar. Using gca(), but will raise in the future. Either provide the *cax* argument to use as the Axes for the Colorbar, provide the *ax* argument to steal space from it, or add *mappable* to an Axes.
#   cbar = fig.colorbar(bar_info)
# <Axes: >

# %%
unique_species = joined['species'].unique()

for species in unique_species:
    print(species)
# Out:
# Mantis religiosa
# Stagmomantis californica
# Litaneutria pacifica
# Iris oratoria
# Stagmomantis limbata
# nan
# Litaneutria ocularis
# Litaneutria minor
# Tenodera sinensis
# Hierodula patellifera
# Litaneutria skinneri
# Litaneutria chaparrali
# Miomantis caffra
# Yersiniops newboldi
# Thesprotia graminis
